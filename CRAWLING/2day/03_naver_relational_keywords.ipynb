# %% [markdown]
# ### 네이버 연관 검색어 수집
# - 정적(static) 웹페이지 데이터 수집
# - BeautifulSoup을 이용하여 HTML 문자열 데이터 parsing

# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup #클래스 import

# %%
# 식별자 컨벤션 : 변수, 함수(snake_case) : 클래스(PascalCase, uppercamelcase)

# %% [markdown]
# #### 1. 웹페이지 분석 : URL

# %%
query = "삼성전자"
url = f"https://search.naver.com/search.naver?query={query}"
url
# Out:
# 'https://search.naver.com/search.naver?query=삼성전자'

# %% [markdown]
# #### 2. request(URL) > response : str(html)    vs 동적은 json
# #### 정적은 파싱하는 방법이 더 복잡하다

# %%
response = requests.get(url)
response
# Out:
# <Response [200]>

# %% [markdown]
# #### 3. str(html) > bs object

# %%
dom = BeautifulSoup(response.text, "html.parser")
dom
# Out:
# <!DOCTYPE html>
#  <html lang="ko"> <head> <meta charset="utf-8"/> <meta content="always" name="referrer"/> <meta content="telephone=no,address=no,email=no" name="format-detection"/> <meta content="width=device-width,initial-scale=1.0,maximum-scale=2.0" name="viewport"/> <meta content="삼성전자 : 네이버 통합검색" property="og:title"> <meta content="https://ssl.pstatic.net/sstatic/search/common/og_v3.png" property="og:image"/> <meta content="'삼성전자'의 네이버 통합검색 결과입니다." property="og:description"/> <meta content="'삼성전자'의 네이버 통합검색 결과입니다." lang="ko" name="description"/> <title>삼성전자 : 네이버 통합검색</title> <link href="https://ssl.pstatic.net/sstatic/search/favicon/favicon_191118_pc.ico" rel="shortcut icon"/> <link href="https://ssl.pstatic.net/sstatic/search/opensearch-description.https.xml" rel="search" title="Naver" type="application/opensearchdescription+xml"><link href="https://ssl.pstatic.net/sstatic/search/pc/css/search1_230216.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/search2_230209.css" rel="stylesheet" type="text/css"/> <link href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_220526.css" rel="stylesheet" type="text/css"/><script type="text/javascript"> if (!String.prototype.trim) { String.prototype.trim = function () { return this.replace(/^[\s\uFEFF\xA0]+|[\s\uFEFF\xA0]+$/g, ''); }; } if (!Array.prototype.indexOf) { Array.prototype.indexOf = function(searchElement, fromIndex) { var k; if (this == null) { throw new TypeError('"this" is null or not defined'); } var o = Object(this); var len = o.length >>> 0; if (len === 0) { return -1; } var n = fromIndex | 0; if (n >= len) { return -1; } k = Math.max(n >= 0 ? n : len - Math.abs(n), 0); while (k < len) { if (k in o && o[k] === searchElement) { return k; } k++; } return -1; }; } if (!Array.prototype.filter) { Array.prototype.filter = function(func, thisArg) { 'use strict'; if (!((typeof func === 'Function' || typeof func === 'function') && this)) throw new TypeError(); var len = this.length >>> 0, res = new Array(len), t = this, c = 0, i = -1; var kValue; if (thisArg === undefined) { while (++i !== len) { if (i in this) { kValue = t[i]; if (func(t[i], i, t)) { res[c++] = kValue; } } } } else { while (++i !== len) { if (i in this) { kValue = t[i]; if (func.call(thisArg, t[i], i, t)) { res[c++] = kValue; } } } } res.length = c; return res; }; } if (typeof(encodeURIComponent) != "function") { encodeURIComponent = function (s) { function toHex (n) { var hexchars = "0123456789ABCDEF" ; return "%%" + hexchars.charAt(n>>4) + hexchars.charAt(n&0xF) ; } var es = "" ; for (var i = 0; i < s.length;) { var c = s.charCodeAt(i++) ; if ((c&0xF800) == 0xD800) { var sc = s.charCodeAt(i++) ; c = ((c-0xD800)<<10) + (sc-0xDC00) + 0x10000 ; } if (!(c&~0x7F)) { if ((c>=65&&c<=90) || (c>=97&&c<=122) || (c>=48&&c<=57) || (c>=45&&c<=46) || c==95 || c==33 || c==126 || (c>=39&&c<=42)) es += String.fromCharCode(c) ; else es += toHex(c) ; } else if (!(c&~0x7FF)) es += toHex(0xC0+(c>>6)) + toHex(c&0x3F) ; else if (!(c&~0xFFFF)) es += toHex(0xE0+(c>>12)) + toHex(0x80+(c>>6&0x3F)) + toHex(0x80+(c&0x3F)) ; else es += toHex(0xF0+(c>>18)) + toHex(0x80+(c>>12&0x3F)) + toHex(0x80+(c>>6&0x3F)) + toHex(0x80+(c&0x3F)) ; } return es ; } } naver = window.naver || {}; naver.search = naver.search || {}; naver.search.abt_param = ""; var g_D = 0 ; naver.search.error = (function () { var errorList = Array() ; return { add : function (s) { errorList.push(s) ; }, clear : function () { delete errorList ; }, get : function (s) { return errorList ; }, getString : function (d) { if (typeof d === 'undefined') d = '|' ; return errorList.join(d) ; } } })(); naver.search.cookie = (function () { return { set : function (key, value, expire, domain) { var cookie = key + "=" + escape(value); if (typeof expire !== 'undefined') { if (expire instanceof Date) { cookie = cookie + "; expires=" + expire.toUTCString(); } else { var exdate = new Date((new Date()).getTime() + expire*1000); cookie = cookie + "; ...
#         .graph_area.open {
#             display: block;
#         }
#         .graph_area {
#             display: none;
#         }
#         .btn_prev.on {
#             display: block;
#         }
#         .btn_prev {
#             display: none;
#         }
#         .btn_next.on {
#             display: block;
#         }
#         .btn_next {
#             display: none;
#         }
#         .cs_stock .cont_grp .grp_nav li.selected a {
#             color: #242424;
#             text-decoration: underline;
#         }
#         .cs_stock .cont_grp .grp_nav li a {
#             color: #808080;
#             text-decoration: none;
#         }
#     </style> <script>(function(){var startApplication=function(){var require=window.require.config({"context":"x0l","paths":{"@lapin/tab":"https://ssl.pstatic.net/sstatic/au/m/kgs/tab/index.min-0.5.4","@plus/button-scroller":"https://ssl.pstatic.net/sstatic/au/m/lapin-plus/button-scroller/index-0.0.2"}});define("jquery",[],function(){return jQuery;});require(["jquery","@lapin/tab","@plus/button-scroller"],function($,tab,createButtonScroller){var key="_cs_stock";var $base=$("."+key);var $buttonScroller=$base.find("._button_scroller");var tabActions=tab($base.get(0),{});$.each($buttonScroller,function(_,el){createButtonScroller({"el":el});});});};var requirejs="https://ssl.pstatic.net/sstatic/au/module/requirejs/require-2.3.5.js";nhn.common.load_js(window.require?null:requirejs,startApplication,true,150);})();</script> <section class="sc_new sp_nnews _prs_nws_all"> <div class="api_subject_bx"> <div class="api_title_area"> <h2 class="api_title">뉴스</h2> <div class="api_title_sub"> <a aria-selected="true" class="api_sub_option" href="?where=news&amp;query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&amp;sort=0&amp;sm=tab_smr&amp;nso=so:r,p:all,a:all" onclick="return goOtherCR(this, 'a=nws_all.sortsim&amp;u='+urlencode(this.href));" role="option">관련도순</a> <a class="api_sub_option" href="?where=news&amp;query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&amp;sort=1&amp;sm=tab_smr&amp;nso=so:dd,p:all,a:all" onclick="return goOtherCR(this, 'a=nws_all.sortdate&amp;u='+urlencode(this.href));" role="option">최신순</a> </div></div><div class="group_news"> <ul class="list_news"> <li class="bx" id="sp_nws_all1"> <div class="news_wrap api_ani_send"> <div class="news_area"> <div class="news_info"> <div class="api_save_group _keep_wrap"> <a aria-pressed="false" class="btn_save _keep_trigger" data-url="http://www.newsis.com/view/?id=NISX20230218_0002197449&amp;cID=10221&amp;pID=10200" href="#" onclick="tCR('a=nws_all*h.kep&amp;r=1&amp;i=88000127_000000000000000011699585&amp;u=javascript'); return false;" role="button"><i class="spnew ico_save">문서 저장하기</i></a> <div class="api_ly_save _keep_save_layer"> <a class="spnew_af item item_save _keep_save" data-cr-off="a=nws_all*h.kepoff&amp;r=1&amp;i=88000127_000000000000000011699585&amp;u=javascript" data-cr-on="a=nws_all*h.kepon&amp;r=1&amp;i=88000127_000000000000000011699585&amp;u=javascript" href="#" role="button">Keep에 저장</a> <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick="return goOtherCR(this,'a=nws_all*h.kephome&amp;r=1&amp;i=88000127_000000000000000011699585&amp;u='+urlencode(this.href));" target="_blank">Keep 바로가기</a> </div></div><div class="info_group"> <a class="info press" href="http://www.newsis.com" onclick="return goOtherCR(this, 'a=nws_all*h.prof&amp;r=1&amp;i=88000127_000000000000000011699585&amp;g=003.0011699585&amp;u='+urlencode(this.href));" target="_blank"><span class="thumb_box"><img alt="" class="thumb" data-lazysrc="https://search.pstatic.net/common/?src=https%3A%2F%2Fmimgnews.pstatic.net%2Fimage%2Fupload%2Foffice_logo%2F003%2F2019%2F02%2F19%2Flogo_003_18_20190219111719.jpg&amp;type=f54_54&amp;expire=24&amp;refresh=true" height="20" onerror="this.src='...';this.className='thumb bg_default_press'" src="..." width="20"/></span>뉴시스<i class="spnew ico_pick">언론사 선정</i></a><span class="info">11시간 전</span><a class="info" href="https://n.news.naver.com/mnews/article/003/0011699585?sid=102" onclick="return goOtherCR(this, 'a=nws_all*h.nav&amp;r=1&amp;i=88000127_000000000000000011699585&amp;u='+urlencode(this.href));" target="_blank">네이버뉴스</a> </div></div><a class="news_tit" href="http://www.newsis.com/view/?id=NISX20230218_0002197449&amp;cID=10221&amp;pID=10200" onclick="return goOtherCR(this, 'a=nws_all*h.tit&amp;r=1&amp;i=88000127_000000000000000011699585&amp;g=003.0011699585&amp;u='+urlencode(this.href));" target="_blank" title="'삼성전자 등 100곳 참여' 내달 2~3일 채용박람회 사전등록">'<mark>삼성전자</mark> 등 100곳 참여' 내달 2~3일 채용박람회 사전등록</a> <div class="news_dsc"> <div class="dsc_wrap"> <a class="api_t ...
# <script type="text/javascript">
#     if (typeof NAVER === "undefined") {
#       NAVER = {};
#     }
#     if (typeof NAVER.SEARCH_AD === "undefined") {
#       NAVER.SEARCH_AD = {};
#     }
#     NAVER.SEARCH_AD.showTooltip = function (element) {
#       var parentElement = $Element(element).parent();
#       var timerAttribute = parentElement.attr("data-timer");
#       if (timerAttribute) {
#         clearTimeout(timerAttribute);
#         parentElement.attr("data-timer", "");
#       }
#       var tooltipElement = $Element(parentElement.query("._tooltip"));
#       tooltipElement.css("display", "inline");
#     };
#     NAVER.SEARCH_AD.hideTooltip = function (element) {
#       var parentElement = $Element(element).parent();
#       if (!parentElement.attr("data-timer")) {
#         var timer = setTimeout(function () {
#           var tooltipElement = $Element(parentElement.query("._tooltip"));
#           tooltipElement.css("display", "none");
#         }, 100);
#         parentElement.attr("data-timer", timer);
#       }
#     };
#
#     var _elAdIndLayerPl = null;
#     var _elAdIndLayerTimePl;
#     var _elDscNcautionPl = null;
#
#     function adInfoShowPl(el) {
#       if (_elAdIndLayerPl) {
#         adInfoHidePl();
#         return false;
#       } else {
#         if (!_elDscNcautionPl) {
#           _elDscNcautionPl = $Element(el).parent();
#         }
#         _elDscNcautionPl._element.style.zIndex = 121;
#         _elAdIndLayerPl = $Element(el).next();
#         _elAdIndLayerPl.show();
#         _elAdIndLayerTimePl = (new Date()).getTime();
#         return true;
#       }
#     }
#
#     function adInfoHidePl() {
#       if (_elAdIndLayerPl) {
#         if (_elDscNcautionPl) {
#           _elDscNcautionPl._element.style.zIndex = 0;
#         }
#         _elAdIndLayerPl.hide();
#         _elAdIndLayerPl = null;
#       }
#     }
#
#     function adInfoHideClickEventHandlerPl(e) {
#       if (_elAdIndLayerTimePl + 200 < (new Date()).getTime()) adInfoHidePl();
#     }
#
#     document.body[window.addEventListener ? 'addEventListener' : 'attachEvent'](window.addEventListener ? "click" : "onclick", adInfoHideClickEventHandlerPl, false);
#   </script>
# <link href="https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/230126/css/nx_powerlink.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/sstatic/search/local/css/maps_openapi_https_150716.css" rel="stylesheet" type="text/css"/>
# <div class="ad_section section _pl_section bg_type_v2">
# <div class="section_head nx_power"><h2>파워링크</h2>
# <div class="dsc_ncaution">
# <span><em class="dsc_ncaution_quotation">‘</em><strong class="dsc_ncaution_keyword">삼성전자</strong><em class="dsc_ncaution_quotation">’</em></span>
# <span class="dsc_ncaution_text">관련 광고입니다.</span>
# <a class="icon_nad_desc" href="javascript:void(0);" onclick="if(adInfoShowPl(this)) goOtherCR(this, 'a=pwl_nop.adset&amp;r=0&amp;i=pwl_nopadset&amp;u='+urlencode(this.href));" title="이 광고가 표시된 이유">이 광고가 표시된 이유</a>
# <div class="ly_ad_dsc" onclick="adInfoHidePl();" style="display:none">
# <p>광고 노출기준은 검색어에 대한 연관성과 광고주의 입찰가이며,
#             이미지 등 추가 링크는 등록한 경우에만 기준에 따라 노출됩니다. <a class="link_help" href="https://saedu.naver.com/help/faq/ncc/view.nhn?faqSeq=704">도움말</a></p>
# <button class="bt_ad_clse" type="button">안내 레이어 닫기</button>
# </div>
# </div>
# <a class="go_register space" href="//saedu.naver.com/adbiz/searchad/intro.nhn" onclick="return goOtherCR(this, 'a=pwl_nop.registration&amp;r=0&amp;i=pwl_nopregistration&amp;u='+urlencode(this.href));" target="_blank">등록 안내</a>
# </div>
# <div class="nad_area" id="power_link_body" impression-event-url="https://event.impression-neo.naver.com/api/v1/events/naver_search/impression?x=...">
# <ul class="lst_type">
# <li class="lst type_more type_subtitle ext_link" num="0" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=F3bStZqWJx8stksxRGpx/v///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=1&amp;i=nad-a001-01-000000211568631&amp;d=' + urlencode('http://www.tmon.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">티몬 삼성전자</span><span class="lnk_tit">티나는 쇼핑, 티몬</span>
# </a>
# <div class="url_area">
# <span class="ico_nad_mark">광고</span>
# <span class="ico_area">
# <span class="ico">
# <span class="sp_nad ico_nlogin" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버 로그인</span>
# <a class="ly_ad _tooltip" href="//nid.naver.com/user2/campaign/introNaverIdLogin.nhn" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=pwl_nop.naverlogin&amp;r=1&amp;i=nad-a001-01-000000211568631&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none">
# <span class="ly_box">
# <span>네이버 아이디로 로그인이 가능합니다.</span>
# <span class="ly_ad_go">서비스 자세히 보기<span class="sp_nad bu"></span></span>
# </span>
# </a>
# </span>
# </span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=F3bStZqWJx8stksxRGpx/v///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=1&amp;i=nad-a001-01-000000211568631&amp;d='+urlencode('http://www.tmon.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">www.tmon.co.kr</a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=F3bStZqWJx8stksxRGpx/v///w==..." onclick="return goOtherCR(this, 'a=pwl_nop.desc&amp;r=1&amp;i=nad-a001-01-000000211568631&amp;d=' + urlencode('http://www.tmon.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank"><strong class="hl">삼성전자</strong>, 누구보다 빠르게 인기가전/디지털제품을 합리적인 가격으로! +쿠폰할인</a>
# </div>
# <ul class="lst_link">
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=YLkGgPgRaK6pBoncYyRTNf///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink1&amp;r=1&amp;i=nad-a001-01-000000211568631&amp;d='+urlencode('http://www.tmon.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">단하루</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=OIvzbsiG4TMKC+tbLe6bsf///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink2&amp;r=1&amp;i=nad-a001-01-000000211568631&amp;d='+urlencode('http://www.tmon.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">만원의행복</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=jFG9z2I8mUyzqt6OWYPjWf///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink3&amp;r=1&amp;i=nad-a001-01-000000211568631&amp;d='+urlencode('http://www.tmon.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">티프레쉬</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=B7TcweynbJus1yyybPD4HP///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink4&amp;r=1&amp;i=nad-a001-01-000000211568631&amp;d='+urlencode('http://www.tmon.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">10분어택</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="lst type_more type_subtitle ext_link type_img" num="1" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=c24VcO+HSTT6DM4Dh1csBf///w==..." onclick="return goOtherCR(this,'a=pwl_nop.image&amp;r=2&amp;i=nad-a001-01-000000215032267&amp;d='+urlencode('http://www.auction.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="링크이미지" class="img_thumb" height="100%" src="https://searchad-phinf.pstatic.net/MjAyMzAyMTVfMTM4/MDAxNjc2NDQzOTQyOTUz.aXB52JOwYhXhTcoKNMA-iSWFpVqKtnhfBZk7wBd8ktMg.1C-9wROTl6cKbJEqUZIyZP4dr9fkdsu4t4b7YEJvAUwg.JPEG/385478-9323afd7-10ca-4b38-a460-2dcf241de68b.jpg?type=f160_160" width="100%"/>
# </a>
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=YsSLvlyeCt1JQL2E39PTSf///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=2&amp;i=nad-a001-01-000000215032267&amp;d=' + urlencode('http://www.auction.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">옥션 삼성전자</span><span class="lnk_tit">매월 전회원 10% 쿠폰!</span>
# </a>
# <div class="url_area">
# <span class="ico_nad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=YsSLvlyeCt1JQL2E39PTSf///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=2&amp;i=nad-a001-01-000000215032267&amp;d='+urlencode('http://www.auction.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">www.auction.co.kr</a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=YsSLvlyeCt1JQL2E39PTSf///w==..." onclick="return goOtherCR(this, 'a=pwl_nop.desc&amp;r=2&amp;i=nad-a001-01-000000215032267&amp;d=' + urlencode('http://www.auction.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank"><strong class="hl">삼성전자</strong> 매월 전회원 10% 쿠폰! 스마일클럽은 3종 쿠폰 추가 제공!</a>
# </div>
# <ul class="lst_link">
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=mwicb1w2d9azOzKOU/FYzv///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink1&amp;r=2&amp;i=nad-a001-01-000000215032267&amp;d='+urlencode('http://www.auction.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">옥션BEST</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=z4AAxUeyh04u/yNIc/hd4P///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink2&amp;r=2&amp;i=nad-a001-01-000000215032267&amp;d='+urlencode('http://www.auction.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">올킬 특가</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=BV90+AnHNkoQQp6Yp14YS////w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink3&amp;r=2&amp;i=nad-a001-01-000000215032267&amp;d='+urlencode('http://www.auction.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">스마일배송</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=ACUzp3WRIK73TWn/ghfFAf///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink4&amp;r=2&amp;i=nad-a001-01-000000215032267&amp;d='+urlencode('http://www.auction.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">스마일클럽</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="lst type_more type_subtitle ext_link type_img" num="2" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=64SRKFwHArMuPGwNPPJcG////w==..." onclick="return goOtherCR(this,'a=pwl_nop.image&amp;r=3&amp;i=nad-a001-01-000000215083139&amp;d='+urlencode('http://www.gmarket.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="링크이미지" class="img_thumb" height="100%" src="https://searchad-phinf.pstatic.net/MjAyMzAyMTVfMiAg/MDAxNjc2NDQwMDEyMjk5.nwOPnKlZf72alFAej4kjp_m4fN6Xr97D8wwumJvrM3Ag.PsE3QBv1rmyAKXC3h20NeL9D2nKD17SyhO7ontDOrQwg.JPEG/284070-588eb04b-988a-4ea2-a60f-6597c83fe4ca.jpg?type=f160_160" width="100%"/>
# </a>
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=aSUeiiZ2QDVRdH3+AvQpt////w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=3&amp;i=nad-a001-01-000000215083139&amp;d=' + urlencode('http://www.gmarket.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">삼성전자 G마켓</span><span class="lnk_tit">누구나 10% 할인!</span>
# </a>
# <div class="url_area">
# <span class="ico_nad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=aSUeiiZ2QDVRdH3+AvQpt////w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=3&amp;i=nad-a001-01-000000215083139&amp;d='+urlencode('http://www.gmarket.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">www.gmarket.co.kr</a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=aSUeiiZ2QDVRdH3+AvQpt////w==..." onclick="return goOtherCR(this, 'a=pwl_nop.desc&amp;r=3&amp;i=nad-a001-01-000000215083139&amp;d=' + urlencode('http://www.gmarket.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank"><strong class="hl">삼성전자</strong> 누구나 즐기는 이달의 쿠폰팩! 누구나 10% 쿠폰 지급!</a>
# </div>
# <ul class="lst_link">
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=Y+r4wI19Df2evQaY3upfHv///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink1&amp;r=3&amp;i=nad-a001-01-000000215083139&amp;d='+urlencode('http://www.gmarket.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">G마켓베스트</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=lVs8MiKkJGr2NRbD8xv5b////w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink2&amp;r=3&amp;i=nad-a001-01-000000215083139&amp;d='+urlencode('http://www.gmarket.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">슈퍼딜특가</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=ZFgXOy/kEniv3wg2uKIwcf///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink3&amp;r=3&amp;i=nad-a001-01-000000215083139&amp;d='+urlencode('http://www.gmarket.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">스마일프레시</a>
# </li>
# <li class="item">
# <a class="link" href="https://adcr.naver.com/adcr?x=84kZi8y39IBf/hs65YS9Df///w==..." onclick="return goOtherCR(this,'a=pwl_nop.sublink4&amp;r=3&amp;i=nad-a001-01-000000215083139&amp;d='+urlencode('http://www.gmarket.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">선물하기</a>
# </li>
# </ul>
# </div>
# </li>
# <li class="lst type_more type_subtitle ext_desc type_img" num="3" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=l+u/sqZm4Mix6DQoqAxQRP///w==..." onclick="return goOtherCR(this,'a=pwl_nop.image&amp;r=4&amp;i=nad-a001-01-000000200646052&amp;d='+urlencode('http://www.gsshop.com')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="링크이미지" class="img_thumb" height="100%" src="https://searchad-phinf.pstatic.net/MjAyMjA5MDdfOTQg/MDAxNjYyNTE2OTg2MjUy.KgO9fF9PYc6UICS2XaNU4xc48A0ujrPbmj7eTaXsIQIg.GTMgCNjsuyKwNRJ2HvRcVzK-24SuAIu_vP1_Xar1524g.JPEG/398521-b7d1d63b-eb2f-455e-93f3-891b716ae680.jpg?type=f160_160" width="100%"/>
# </a>
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=UwgsQ3tk6g80stuXjVjHkP///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=4&amp;i=nad-a001-01-000000200646052&amp;d=' + urlencode('http://www.gsshop.com') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">GS SHOP 삼성전자</span><span class="lnk_tit">방송알림 3천원 쿠폰 증정!</span>
# </a>
# <div class="url_area">
# <span class="ico_nad_mark">광고</span>
# <span class="ico_area">
# <span class="ico">
# <span class="sp_nad ico_nlogin" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버 로그인</span>
# <a class="ly_ad _tooltip" href="//nid.naver.com/user2/campaign/introNaverIdLogin.nhn" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=pwl_nop.naverlogin&amp;r=4&amp;i=nad-a001-01-000000200646052&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none">
# <span class="ly_box">
# <span>네이버 아이디로 로그인이 가능합니다.</span>
# <span class="ly_ad_go">서비스 자세히 보기<span class="sp_nad bu"></span></span>
# </span>
# </a>
# </span>
# </span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=UwgsQ3tk6g80stuXjVjHkP///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=4&amp;i=nad-a001-01-000000200646052&amp;d='+urlencode('http://www.gsshop.com')+'&amp;u='+urlencode(this.href));" target="_blank">www.gsshop.com</a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=UwgsQ3tk6g80stuXjVjHkP///w==..." onclick="return goOtherCR(this, 'a=pwl_nop.desc&amp;r=4&amp;i=nad-a001-01-000000200646052&amp;d=' + urlencode('http://www.gsshop.com') + '&amp;u='+ urlencode(this.href));" target="_blank"><strong class="hl">삼성전자</strong>, 가볍지만 스마트한 일상의 시작 인기상품 특가! 행사카드최대7%즉시할인</a>
# </div>
# <div class="desc_area promotion">
# <em class="point">이벤트</em>
#               이달의 GS 혜택 확인하기
#             </div>
# </div>
# </li>
# <li class="lst type_more type_subtitle ext_desc type_img" num="4" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=DSMm5GGh0GCbYmMcRgvNgP///w==..." onclick="return goOtherCR(this,'a=pwl_nop.image&amp;r=5&amp;i=nad-a001-01-000000211110576&amp;d='+urlencode('http://WWW.SSG.COM')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="링크이미지" class="img_thumb" height="100%" src="https://searchad-phinf.pstatic.net/MjAyMjA4MDNfNzkg/MDAxNjU5NTE3Njk1NDE4.T8_ReGodKxn7ErkBxmVpP-X1tWCVBjJP1DR1HkhlNosg.PeXAktdWYmyj7I8Ul8XBdfTeOOFhWVwF-BnWwJReyw0g.PNG/780924-792d9bb2-42e8-4ee7-9008-20681bab1c69.PNG?type=f160_160" width="100%"/>
# </a>
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=q689U7VAgr6gVfFbxadXmv///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=5&amp;i=nad-a001-01-000000211110576&amp;d=' + urlencode('http://WWW.SSG.COM') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">SSG닷컴 삼성전자</span><span class="lnk_tit">최대 20% 할인쿠폰 증정!</span>
# </a>
# <div class="url_area">
# <span class="ico_nad_mark">광고</span>
# <span class="ico_area">
# <span class="ico">
# <span class="sp_nad ico_nlogin" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버 로그인</span>
# <a class="ly_ad _tooltip" href="//nid.naver.com/user2/campaign/introNaverIdLogin.nhn" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=pwl_nop.naverlogin&amp;r=5&amp;i=nad-a001-01-000000211110576&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none">
# <span class="ly_box">
# <span>네이버 아이디로 로그인이 가능합니다.</span>
# <span class="ly_ad_go">서비스 자세히 보기<span class="sp_nad bu"></span></span>
# </span>
# </a>
# </span>
# </span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=q689U7VAgr6gVfFbxadXmv///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=5&amp;i=nad-a001-01-000000211110576&amp;d='+urlencode('http://WWW.SSG.COM')+'&amp;u='+urlencode(this.href));" target="_blank">WWW.SSG.COM</a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=q689U7VAgr6gVfFbxadXmv///w==..." onclick="return goOtherCR(this, 'a=pwl_nop.desc&amp;r=5&amp;i=nad-a001-01-000000211110576&amp;d=' + urlencode('http://WWW.SSG.COM') + '&amp;u='+ urlencode(this.href));" target="_blank">가전 쇼핑도 역시 쓱! 가전 특가의 헤택. 알뜰쇼핑 SSG 쿠폰 + 청구 할인!</a>
# </div>
# <div class="desc_area promotion">
# <em class="point">할인</em>
#               장바구니+멤버십혜택
#             </div>
# </div>
# </li>
# <li class="lst type_more type_subtitle type_img" num="5" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=922GJic7hq1VywnYo81oqv///w==..." onclick="return goOtherCR(this,'a=pwl_nop.image&amp;r=6&amp;i=nad-a001-01-000000199973361&amp;d='+urlencode('http://www.enuri.com')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="링크이미지" class="img_thumb" height="100%" src="https://searchad-phinf.pstatic.net/MjAyMjA5MDJfMjIx/MDAxNjYyMDgzMzY5MTQz.E0r1v9CYhO97sKqUIUShaqPRLG58joBCN60wwJoEihog.eferf0lVfuQVbcHN8_zFRK-6W2UARVotpQ8-21XTrdAg.JPEG/105961-e4c9570b-d954-4351-ade8-9d3935a5e188.jpg?type=f160_160" width="100%"/>
# </a>
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=DMMI2EC5OseADolYvNtSvv///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=6&amp;i=nad-a001-01-000000199973361&amp;d=' + urlencode('http://www.enuri.com') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">에누리 삼성전자</span><span class="lnk_tit">노트북 구매 시 5만점 적립</span><span class="lnk_tit">구매금액 최대 1.5% 적립</span>
# </a>
# <div class="url_area">
# <span class="ico_nad_mark">광고</span>
# <span class="ico_area">
# <span class="ico">
# <span class="sp_nad ico_nlogin" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버 로그인</span>
# <a class="ly_ad _tooltip" href="//nid.naver.com/user2/campaign/introNaverIdLogin.nhn" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=pwl_nop.naverlogin&amp;r=6&amp;i=nad-a001-01-000000199973361&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none">
# <span class="ly_box">
# <span>네이버 아이디로 로그인이 가능합니다.</span>
# <span class="ly_ad_go">서비스 자세히 보기<span class="sp_nad bu"></span></span>
# </span>
# </a>
# </span>
# </span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=DMMI2EC5OseADolYvNtSvv///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=6&amp;i=nad-a001-01-000000199973361&amp;d='+urlencode('http://www.enuri.com')+'&amp;u='+urlencode(this.href));" target="_blank">www.enuri.com</a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=DMMI2EC5OseADolYvNtSvv///w==..." onclick="return goOtherCR(this, 'a=pwl_nop.desc&amp;r=6&amp;i=nad-a001-01-000000199973361&amp;d=' + urlencode('http://www.enuri.com') + '&amp;u='+ urlencode(this.href));" target="_blank">노트북 최저가는 에누리 가격비교에서! <strong class="hl">삼성전자</strong>, 평균 8% 추가 혜택</a>
# </div>
# </div>
# </li>
# <li class="lst type_more type_subtitle type_img" num="6" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <a class="lnk_thumb" href="https://adcr.naver.com/adcr?x=LmfEqfxmdOOAv2Ekrpo9C////w==..." onclick="return goOtherCR(this,'a=pwl_nop.image&amp;r=7&amp;i=nad-a001-01-000000210862178&amp;d='+urlencode('http://www.e-himart.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">
# <img alt="링크이미지" class="img_thumb" height="100%" src="https://searchad-phinf.pstatic.net/MjAyMjAxMDdfNDEg/MDAxNjQxNTM4MTUwOTc1.KeQGw3Enr86XuF7J6bEafbnzFKTWWLAmDev1xNizoI8g.w1Kx5J6OqxK7-pF2W6UtByni-edGX222iSxGCNybcekg.PNG/418677-8fa913c2-4836-41f1-887a-117309a13606.png?type=f160_160" width="100%"/>
# </a>
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=kyPMR24v4USlS9hOcPd+OP///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=7&amp;i=nad-a001-01-000000210862178&amp;d=' + urlencode('http://www.e-himart.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">하이마트 삼성전자</span><span class="lnk_tit">가전은 역시 하이마트 공식몰</span>
# </a>
# <div class="url_area">
# <span class="ico_nad_mark">광고</span>
# <span class="ico_area">
# <span class="ico">
# <span alt="네이버페이" class="sp_nad ico_npay" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버페이</span>
# <a class="ly_ad _tooltip" href="//pay.naver.com/about?frm=sa" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=pwl_nop.checkout&amp;r=7&amp;i=nad-a001-01-000000210862178&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none" target="_blank">
# <span class="ly_box">
# <span>네이버 아이디 하나로 간편구매</span>
# <span class="ly_ad_go"><strong>Naver Pay</strong> 서비스 보기<span class="sp_nad bu"></span></span>
# </span>
# </a>
# </span>
# </span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=kyPMR24v4USlS9hOcPd+OP///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=7&amp;i=nad-a001-01-000000210862178&amp;d='+urlencode('http://www.e-himart.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">www.e-himart.co.kr</a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=kyPMR24v4USlS9hOcPd+OP///w==..." onclick="return goOtherCR(this, 'a=pwl_nop.desc&amp;r=7&amp;i=nad-a001-01-000000210862178&amp;d=' + urlencode('http://www.e-himart.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">하이마트 <strong class="hl">삼성전자</strong> 특가! 풍성한 카드할인+특가혜택을 만나보세요 오늘 배송부터 프리미엄 배송까지! 구매 후에도 함께하는 특별한 하이마트 배송서비스</a>
# </div>
# </div>
# </li>
# <li class="lst" num="7" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=qEid1Go87KPmo34ICdItBf///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=8&amp;i=nad-a001-01-000000082647016&amp;d=' + urlencode('http://first-rental.net') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">LG헬로 삼성전자렌탈 특가</span>
# </a>
# <div class="url_area">
# <span class="ico_nad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=qEid1Go87KPmo34ICdItBf///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=8&amp;i=nad-a001-01-000000082647016&amp;d='+urlencode('http://first-rental.net')+'&amp;u='+urlencode(this.href));" target="_blank">first-rental.net</a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=qEid1Go87KPmo34ICdItBf///w==..." onclick="return goOtherCR(this, 'a=pwl_nop.desc&amp;r=8&amp;i=nad-a001-01-000000082647016&amp;d=' + urlencode('http://first-rental.net') + '&amp;u='+ urlencode(this.href));" target="_blank">푸짐한사은품, 삼성 인기가전 초기비용 0원, 배송비설치비무료, 만기후 소유권이전</a>
# </div>
# </div>
# </li>
# <li class="lst" num="8" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=BH2fheUWWx/49+BAlb2DjP///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=9&amp;i=nad-a001-01-000000221065251&amp;d=' + urlencode('http://www.11st.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">11번가 삼성전자 특가</span>
# </a>
# <div class="url_area">
# <span class="ico_nad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=BH2fheUWWx/49+BAlb2DjP///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=9&amp;i=nad-a001-01-000000221065251&amp;d='+urlencode('http://www.11st.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">www.11st.co.kr</a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=BH2fheUWWx/49+BAlb2DjP///w==..." onclick="return goOtherCR(this, 'a=pwl_nop.desc&amp;r=9&amp;i=nad-a001-01-000000221065251&amp;d=' + urlencode('http://www.11st.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">고품질 제품으로 편리함 UP! <strong class="hl">삼성전자</strong> 11번가에서 할인가에 쇼핑하자</a>
# </div>
# </div>
# </li>
# <li class="lst" num="9" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=DkEBQ1qaZGuqpfnRhEzcq////w==...&amp;p=0" onclick="return goOtherCR(this, 'a=pwl_nop.tit&amp;r=10&amp;i=nad-a001-01-000000207806556&amp;d=' + urlencode('https://www.lotteon.com') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">삼성전자, 롯데ON</span>
# </a>
# <div class="url_area">
# <span class="ico_nad_mark">광고</span>
# <span class="ico_area">
# <span class="ico">
# <span alt="네이버페이" class="sp_nad ico_npay" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버페이</span>
# <a class="ly_ad _tooltip" href="//pay.naver.com/about?frm=sa" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=pwl_nop.checkout&amp;r=10&amp;i=nad-a001-01-000000207806556&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none" target="_blank">
# <span class="ly_box">
# <span>네이버 아이디 하나로 간편구매</span>
# <span class="ly_ad_go"><strong>Naver Pay</strong> 서비스 보기<span class="sp_nad bu"></span></span>
# </span>
# </a>
# </span>
# </span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=DkEBQ1qaZGuqpfnRhEzcq////w==...&amp;p=1" onclick="return goOtherCR(this, 'a=pwl_nop.url&amp;r=10&amp;i=nad-a001-01-000000207806556&amp;d='+urlencode('https://www.lotteon.com')+'&amp;u='+urlencode(this.href));" target="_blank">www.lotteon.com</a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=DkEBQ1qaZGuqpfnRhEzcq////w==..." onclick="return goOtherCR(this, 'a=pwl_nop.desc&amp;r=10&amp;i=nad-a001-01-000000207806556&amp;d=' + urlencode('https://www.lotteon.com') + '&amp;u='+ urlencode(this.href));" target="_blank">취향을, 브랜드를, 혜택을 발견하는 즐거움. 지금 롯데온에서 만나보세요.</a>
# </div>
# </div>
# </li>
# </ul>
# <div class="section_more">
# <a class="go_site" href="https://ad.search.naver.com/search.naver?where=ad&amp;query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&amp;referenceId=h%2F4G7lprvhGssAebu4Gssssss8R-385371" onclick="return goOtherCR(this, 'a=pwl_nop.more&amp;r=1&amp;i=pwl_nopmore&amp;u='+urlencode(this.href));" target="_blank">
#           더보기<i class="icon_arrow sp_nad"></i></a>
# </div>
# </div>
# <a class="nad_banner" href="https://help.pay.naver.com/faq/alias/powerad01.help" onclick="return goOtherCR(this, 'a=mib_pwl.banner&amp;r=0&amp;i=mib_pwlbanner&amp;u='+urlencode(this.href));" target="_blank">
# <span class="sp_nad ico_npay">네이버페이</span>파워링크에서 네이버페이로 결제하면 추가 적립
#     </a>
# </div>
# <script type="text/javascript">
#       (function() {
#           var createPlaceImageConveyer = function() {
#               var prev = document.getElementById("_place_prev_button");
#               var next = document.getElementById("_place_next_button");
#               if (prev == null || next == null) {
#                   return;
#               }
#               prev.style.display = "none";
#               var require = window.require.config({
#                   context: "impression_neo_place_extension",
#                   paths: {
#                       "egjsConveyer": "https://ssl.pstatic.net/adimg3.search/imp/nx/power/pc/220822/js/egjs-conveyer.min.k253dc24"
#                   }
#               });
#               require(["egjsConveyer"], function(egjsConveyer) {
#                   var conveyer = new egjsConveyer("#place_flicking", { autoInit: false, preventClickOnDrag: true});
#
#
#                   conveyer.subscribe("isReachStart", function(isReachStart) {
#                       prev.style.display = isReachStart ? "none" : "block";
#                   });
#
#                   conveyer.subscribe("isReachEnd", function(isReachEnd) {
#                       next.style.display = isReachEnd ? "none" : "block";
#                   });
#                   conveyer.init();
#
#                   if (!conveyer.isReachEnd) {
#                       next.style.display = "block";
#                   }
#
#                   prev.addEventListener("click", function() {
#                       conveyer.scrollIntoView("start", {
#                           align: "end",
#                           duration: 500,
#                           excludeStand: true,
#                       });
#                   });
#                   next.addEventListener("click", function() {
#                       conveyer.scrollIntoView("end", {
#                           align: "start",
#                           duration: 500,
#                           excludeStand: true,
#                       });
#                   });
#               });
#           };
#           nhn.common.load_js(null, createPlaceImageConveyer, true, 150);
#       })();
#   </script>
# <section class="sc_new sp_ntotal _prs_web_gen _web_gen _sp_ntotal _kin_snippet_root_web_gen _project_channel_root_web_gen _fe_kin_snippet"> <div class="api_subject_bx type_noline"> <ul class="lst_total"> <li class="bx" id="web_1"> <div class="total_wrap api_ani_send"> <div class="api_save_group _keep_wrap"> <a class="btn_save _keep_trigger" data-url="https://namu.wiki/w/%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90" href="#" onclick="tCR('a=web_gen.kep&amp;r=&amp;i=&amp;u=javascript');" role="button"><i class="spnew ico_save">문서 저장하기</i></a> <div class="api_ly_save _keep_save_layer"> <a class="spnew_af item item_save _keep_save" data-cr-off="a=web_gen.kepoff" data-cr-on="a=web_gen.kepon" href="#" role="button">Keep에 저장</a> <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick="goOtherCR(this,'a=web_gen.kephome&amp;r=1&amp;i=a00000fa_5f5df0d13c98bf39cbea3fbd&amp;u='+urlencode(this.href));" target="_blank">Keep 바로가기</a> </div> </div> <div class="total_source_group"> <div class="total_source"> <div class="source_box"> <a class="thumb" href="https://namu.wiki/w/%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90" onclick="goOtherCR(this,'a=web_gen*w.link&amp;r=1&amp;i=a00000fa_5f5df0d13c98bf39cbea3fbd&amp;u='+urlencode(this.href));" target="_blank"><img alt="" height="15" src="https://search.pstatic.net/sunny/?src=https%3A%2F%2Fnamu.wiki%2Ffavicon-192.png&amp;type=f30_30_png_expire24" width="15"/></a> <a class="txt elss" href="https://namu.wiki/w/%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90" onclick="goOtherCR(this,'a=web_gen*w.link&amp;r=1&amp;i=a00000fa_5f5df0d13c98bf39cbea3fbd&amp;u='+urlencode(this.href));" target="_blank">namu.wiki<i class="divide">›</i>삼성전자 </a> </div> </div> </div> <div class="total_group"> <div class="total_dsc_wrap"> <div class="total_tit_box"> <div class="total_tit"> <a class="link_tit" href="https://namu.wiki/w/%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90" onclick="goOtherCR(this,'a=web_gen*c.link&amp;r=1&amp;i=a00000fa_5f5df0d13c98bf39cbea3fbd&amp;u='+urlencode(this.href));" target="_blank"> <mark>삼성전자</mark> - 나무위키 </a> </div> </div> <a class="total_dsc" href="https://namu.wiki/w/%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90" onclick="goOtherCR(this,'a=web_gen*c.link&amp;r=1&amp;i=a00000fa_5f5df0d13c98bf39cbea3fbd&amp;u='+urlencode(this.href));" target="_blank"> <div class="api_txt_lines dsc_txt"> <mark>삼성전자</mark>(SAMSUNG ELECTRONICS)는 대한민국에 본사를 두고 <mark>전자</mark>제품을 제조하는 대한민국 최대의 다국적 기업이다. 창사 이래로 세계 시장에서 매우 큰 성공을 이루어냈으며, 현재 가장 인지도 높은 한국 대표 기업으로 자리매김하였다.</div> </a> <a class="total_info" href="https://namu.wiki/w/%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90" onclick="goOtherCR(this,'a=web_gen*c.link&amp;r=1&amp;i=a00000fa_5f5df0d13c98bf39cbea3fbd&amp;u='+urlencode(this.href));" target="_blank"> <div class="item"> <div class="tit">업종</div> <div class="info">이동전화기 제조업</div> </div> <div class="item"> <div class="tit">대표이사</div> <div class="info">한종희, 경계현</div> </div> <div class="item"> <div class="tit">창립일</div> <div class="info">1969년 1월 13일 ( 54주년 )</div> </div> <div class="item"> <div class="tit">창업주</div> <div class="info">이병철</div> </div> </a> </div> </div> </div> </li> <li class="bx" id="web_2"> <div class="total_wrap api_ani_send"> <div class="api_save_group _keep_wrap"> <a class="btn_save _keep_trigger" data-url="https://blog.naver.com/samsung_korea" href="#" onclick="tCR('a=web_gen.kep&amp;r=&amp;i=&amp;u=javascript');" role="button"><i class="spnew ico_save">문서 저장하기</i></a> <div class="api_ly_save _keep_save_layer"> <a class="spnew_af item item_save _keep_save" data-cr-off="a=web_gen.kepoff" data-cr-on="a=web_gen.kepon" href="#" role="button">Keep에 저장</a> <a class="spnew_af item item_quick" href="https://keep.naver.com/" onclick="goOtherCR(this,'a=web_gen.kephome&amp;r=2&amp;i=a00000fa_249e7744aa599c4f290f749e&amp;u='+urlencode(this.href));" target="_blank">Keep 바로가기</a> </div> </div> <div class="total_source_group"> <div class="total_source"> <div class="source_box"> <a class="thumb" href="https://blog.naver.com/samsung_korea" o ...
# ...
#         _elAdIndLayerBz.show();
#         _elAdIndLayerTimeBz = (new Date()).getTime();
#         return true;
#       }
#     }
#
#     function adInfoHideBz() {
#       if (_elAdIndLayerBz) {
#         if (_elDscNcautionBz) {
#           _elDscNcautionBz._element.style.zIndex = 0;
#         }
#         _elAdIndLayerBz.hide();
#         _elAdIndLayerBz = null;
#       }
#     }
#
#     function adInfoHideClickEventHandlerBz(e) {
#       if (_elAdIndLayerTimeBz + 200 < (new Date()).getTime()) adInfoHideBz();
#     }
#
#     document.body[window.addEventListener ? 'addEventListener' : 'attachEvent'](window.addEventListener ? "click" : "onclick", adInfoHideClickEventHandlerBz, false);
#   </script>
# <div class="ad_section section _bz_section bg_type_v2">
# <div class="section_head"><h2>비즈사이트</h2>
# <div class="dsc_ncaution">
# <span><em class="dsc_ncaution_quotation">‘</em>
# <strong class="dsc_ncaution_keyword">삼성전자</strong>
# <em class="dsc_ncaution_quotation">’</em>
# </span>
# <span class="dsc_ncaution_text">관련 광고입니다.</span>
# <a class="icon_nad_desc" href="javascript:void(0);" onclick="if(adInfoShowBz(this)) goOtherCR(this, 'a=biz_nop.adset&amp;r=0&amp;i=biz_nopadset&amp;u='+urlencode(this.href));" title="이 광고가 표시된 이유">이 광고가 표시된 이유</a>
# <div class="ly_ad_dsc" onclick="adInfoHideBz();" style="display:none">
# <p>광고 노출기준은 검색어에 대한 연관성과 광고주의 입찰가입니다.</p>
# <button class="bt_ad_clse" title="안내 레이어 닫기" type="button">안내 레이어 닫기</button>
# </div>
# </div>
# <a class="go_register space" href="//saedu.naver.com/adbiz/searchad/intro.nhn" onclick="return goOtherCR(this, 'a=biz_nop.registration&amp;r=0&amp;i=biz_nopregistration&amp;u='+urlencode(this.href));" target="_blank">등록 안내</a>
# </div>
# <div class="nad_area" id="biz_site_body" impression-event-url="https://event.impression-neo.naver.com/api/v1/events/naver_search/impression?x=l9zdoNvqKogT8crUjFAX4_j-...">
# <ul class="lst_type">
# <li class="lst" num="0" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=DE5UriV7XqJ57t2rWEPT4P///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=biz_nop.tit&amp;r=1&amp;i=nad-a001-01-000000224272875&amp;d=' + urlencode('https://smartstore.naver.com/jm49') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">가전이 필요할때 제이프리몰</span>
# </a>
# <div class="url_area">
# <span class="ico_nad_mark">광고</span>
# <span class="ico_area">
# <span class="ico">
# <span alt="네이버페이" class="sp_nad ico_npay_plus" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" tabindex="0">네이버페이</span>
# <a class="ly_ad _tooltip" href="//pay.naver.com/about?frm=sa" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=biz_nop.checkout&amp;r=1&amp;i=nad-a001-01-000000224272875&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none" target="_blank">
# <span class="ly_box">
# <span>네이버 아이디 하나로 간편구매</span>
# <span class="ly_ad_go"><strong>Naver Pay</strong> 서비스 보기<span class="sp_nad bu"></span></span>
# </span>
# </a>
# </span>
# </span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=DE5UriV7XqJ57t2rWEPT4P///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=biz_nop.url&amp;r=1&amp;i=nad-a001-01-000000224272875&amp;d='+urlencode('https://smartstore.naver.com/jm49')+'&amp;u='+urlencode(this.href));" target="_blank">smartstore.naver.com/jm49</a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=DE5UriV7XqJ57t2rWEPT4P///w==..." onclick="return goOtherCR(this, 'a=biz_nop.desc&amp;r=1&amp;i=nad-a001-01-000000224272875&amp;d=' + urlencode('https://smartstore.naver.com/jm49') + '&amp;u='+ urlencode(this.href));" target="_blank">냉장고 세탁기 건조기 보조배터리 등 전자제품 다양한 품목 세일중입니다.</a>
# </div>
# </div>
# </li>
# <li class="lst" num="1" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=ol+4uB1HC7fmasjiosN2WP///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=biz_nop.tit&amp;r=2&amp;i=nad-a001-01-000000108353660&amp;d=' + urlencode('http://www.danawa.com') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">삼성전자 다나와</span>
# </a>
# <div class="url_area">
# <span class="ico_nad_mark">광고</span>
# <span class="ico_area">
# <span class="ico">
# <span class="sp_nad ico_nlogin" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);">네이버 로그인</span>
# <a class="ly_ad _tooltip" href="//nid.naver.com/user2/campaign/introNaverIdLogin.nhn" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=biz_nop.naverlogin&amp;r=2&amp;i=nad-a001-01-000000108353660&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none">
# <span class="ly_box">
# <span>네이버 아이디로 로그인이 가능합니다.</span>
# <span class="ly_ad_go">서비스 자세히 보기<span class="sp_nad bu"></span></span>
# </span>
# </a>
# </span>
# </span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=ol+4uB1HC7fmasjiosN2WP///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=biz_nop.url&amp;r=2&amp;i=nad-a001-01-000000108353660&amp;d='+urlencode('http://www.danawa.com')+'&amp;u='+urlencode(this.href));" target="_blank">www.danawa.com</a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=ol+4uB1HC7fmasjiosN2WP///w==..." onclick="return goOtherCR(this, 'a=biz_nop.desc&amp;r=2&amp;i=nad-a001-01-000000108353660&amp;d=' + urlencode('http://www.danawa.com') + '&amp;u='+ urlencode(this.href));" target="_blank">최신 스마트폰, 공기계, 해외폰, <strong class="hl">삼성전자</strong>, 추가할인까지 다나와!</a>
# </div>
# </div>
# </li>
# <li class="lst" num="2" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=vW5AuGaaJoGdvOnBzeLkOf///w==...&amp;p=0" onclick="return goOtherCR(this, 'a=biz_nop.tit&amp;r=3&amp;i=nad-a001-01-000000210579943&amp;d=' + urlencode('http://www.shinsegaetvshopping.com') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">신세계라이브쇼핑 삼성전자</span>
# </a>
# <div class="url_area">
# <span class="ico_nad_mark">광고</span>
# <span class="ico_area">
# <span class="ico">
# <span class="sp_nad ico_nlogin" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);">네이버 로그인</span>
# <a class="ly_ad _tooltip" href="//nid.naver.com/user2/campaign/introNaverIdLogin.nhn" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=biz_nop.naverlogin&amp;r=3&amp;i=nad-a001-01-000000210579943&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none">
# <span class="ly_box">
# <span>네이버 아이디로 로그인이 가능합니다.</span>
# <span class="ly_ad_go">서비스 자세히 보기<span class="sp_nad bu"></span></span>
# </span>
# </a>
# </span>
# </span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=vW5AuGaaJoGdvOnBzeLkOf///w==...&amp;p=1" onclick="return goOtherCR(this, 'a=biz_nop.url&amp;r=3&amp;i=nad-a001-01-000000210579943&amp;d='+urlencode('http://www.shinsegaetvshopping.com')+'&amp;u='+urlencode(this.href));" target="_blank">www.shinsegaetvshopping.com</a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=vW5AuGaaJoGdvOnBzeLkOf///w==..." onclick="return goOtherCR(this, 'a=biz_nop.desc&amp;r=3&amp;i=nad-a001-01-000000210579943&amp;d=' + urlencode('http://www.shinsegaetvshopping.com') + '&amp;u='+ urlencode(this.href));" target="_blank">신규가입 즉시 10%할인, 앱 최대 35%혜택, 소형가전부터 대형/생활가전까지</a>
# </div>
# </div>
# </li>
# <li class="lst" num="3" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=T3uiZqp9xT7RbTa7odbeW////w==...&amp;p=0" onclick="return goOtherCR(this, 'a=biz_nop.tit&amp;r=4&amp;i=nad-a001-01-000000191405804&amp;d=' + urlencode('http://www.wemakeprice.com') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">삼성전자 위메프</span>
# </a>
# <div class="url_area">
# <span class="ico_nad_mark">광고</span>
# <span class="ico_area">
# <span class="ico">
# <span class="sp_nad ico_nlogin" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);">네이버 로그인</span>
# <a class="ly_ad _tooltip" href="//nid.naver.com/user2/campaign/introNaverIdLogin.nhn" onblur="NAVER.SEARCH_AD.hideTooltip(this);" onclick="return goOtherCR(this, 'a=biz_nop.naverlogin&amp;r=4&amp;i=nad-a001-01-000000191405804&amp;u='+urlencode(this.href));" onfocus="NAVER.SEARCH_AD.showTooltip(this);" onmouseout="NAVER.SEARCH_AD.hideTooltip(this);" onmouseover="NAVER.SEARCH_AD.showTooltip(this);" style="display:none">
# <span class="ly_box">
# <span>네이버 아이디로 로그인이 가능합니다.</span>
# <span class="ly_ad_go">서비스 자세히 보기<span class="sp_nad bu"></span></span>
# </span>
# </a>
# </span>
# </span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=T3uiZqp9xT7RbTa7odbeW////w==...&amp;p=1" onclick="return goOtherCR(this, 'a=biz_nop.url&amp;r=4&amp;i=nad-a001-01-000000191405804&amp;d='+urlencode('http://www.wemakeprice.com')+'&amp;u='+urlencode(this.href));" target="_blank">www.wemakeprice.com</a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=T3uiZqp9xT7RbTa7odbeW////w==..." onclick="return goOtherCR(this, 'a=biz_nop.desc&amp;r=4&amp;i=nad-a001-01-000000191405804&amp;d=' + urlencode('http://www.wemakeprice.com') + '&amp;u='+ urlencode(this.href));" target="_blank"><strong class="hl">삼성전자</strong>, 식품부터 해외직구까지 투데이대표특가! 매일밤00시 최대15% 추가할인</a>
# </div>
# </div>
# </li>
# <li class="lst" num="4" onmouseout="jindo.$Element(this).removeClass('ad_hover');" onmouseover="jindo.$Element(this).addClass('ad_hover');">
# <div class="inner">
# <a class="lnk_head" href="https://adcr.naver.com/adcr?x=tZdBr+Vd3ymaXLL4QhT2H////w==...&amp;p=0" onclick="return goOtherCR(this, 'a=biz_nop.tit&amp;r=5&amp;i=nad-a001-01-000000171108020&amp;d=' + urlencode('http://rental-joy.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">
# <span class="lnk_tit">삼성전자 전문렌탈점 렌탈조이</span>
# </a>
# <div class="url_area">
# <span class="ico_nad_mark">광고</span>
# <a class="lnk_url" href="https://adcr.naver.com/adcr?x=tZdBr+Vd3ymaXLL4QhT2H////w==...&amp;p=1" onclick="return goOtherCR(this, 'a=biz_nop.url&amp;r=5&amp;i=nad-a001-01-000000171108020&amp;d='+urlencode('http://rental-joy.co.kr')+'&amp;u='+urlencode(this.href));" target="_blank">rental-joy.co.kr</a>
# </div>
# <div class="desc_area">
# <a class="link_desc" href="https://adcr.naver.com/adcr?x=tZdBr+Vd3ymaXLL4QhT2H////w==..." onclick="return goOtherCR(this, 'a=biz_nop.desc&amp;r=5&amp;i=nad-a001-01-000000171108020&amp;d=' + urlencode('http://rental-joy.co.kr') + '&amp;u='+ urlencode(this.href));" target="_blank">LG,삼성등 브랜드 최신 가전제품 다량보유.친절상담, 신속납품,사은품 증정</a>
# </div>
# </div>
# </li>
# </ul>
# <div class="section_more">
# <a class="go_site" href="https://ad.search.naver.com/search.naver?where=ad&amp;query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&amp;referenceId=h%2F4G7lprvhGssAebu4Gssssss8R-385371" onclick="return goOtherCR(this, 'a=biz_nop.more&amp;r=1&amp;i=bizmore&amp;u='+urlencode(this.href));" target="_blank">
#           더보기<i class="icon_arrow sp_nad"></i></a>
# </div>
# </div>
# </div>
# <div class="api_sc_page_wrap"> <div class="sc_page"> <a aria-disabled="true" class="btn_prev" role="button"><i class="spnew ico_page_arr">이전</i></a> <div class="sc_page_inner"> <a aria-pressed="true" class="btn" href="?query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&amp;sm=tab_pge&amp;where=nexearch" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=1&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">1</a> <a aria-pressed="false" class="btn" href="?display=15&amp;f=&amp;filetype=0&amp;page=2&amp;query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&amp;research_url=&amp;sm=tab_pge&amp;start=1&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=2&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">2</a> <a aria-pressed="false" class="btn" href="?display=15&amp;f=&amp;filetype=0&amp;page=3&amp;query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&amp;research_url=&amp;sm=tab_pge&amp;start=16&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=3&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">3</a> <a aria-pressed="false" class="btn" href="?display=15&amp;f=&amp;filetype=0&amp;page=4&amp;query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&amp;research_url=&amp;sm=tab_pge&amp;start=31&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=4&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">4</a> <a aria-pressed="false" class="btn" href="?display=15&amp;f=&amp;filetype=0&amp;page=5&amp;query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&amp;research_url=&amp;sm=tab_pge&amp;start=46&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=5&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">5</a> <a aria-pressed="false" class="btn" href="?display=15&amp;f=&amp;filetype=0&amp;page=6&amp;query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&amp;research_url=&amp;sm=tab_pge&amp;start=61&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=6&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">6</a> <a aria-pressed="false" class="btn" href="?display=15&amp;f=&amp;filetype=0&amp;page=7&amp;query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&amp;research_url=&amp;sm=tab_pge&amp;start=76&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=7&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">7</a> <a aria-pressed="false" class="btn" href="?display=15&amp;f=&amp;filetype=0&amp;page=8&amp;query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&amp;research_url=&amp;sm=tab_pge&amp;start=91&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=8&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">8</a> <a aria-pressed="false" class="btn" href="?display=15&amp;f=&amp;filetype=0&amp;page=9&amp;query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&amp;research_url=&amp;sm=tab_pge&amp;start=106&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=9&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">9</a> <a aria-pressed="false" class="btn" href="?display=15&amp;f=&amp;filetype=0&amp;page=10&amp;query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&amp;research_url=&amp;sm=tab_pge&amp;start=121&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=10&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button">10</a> </div> <a aria-disabled="false" class="btn_next" href="?display=15&amp;f=&amp;filetype=0&amp;page=11&amp;query=%EC%82%BC%EC%84%B1%EC%A0%84%EC%9E%90&amp;research_url=&amp;sm=tab_pge&amp;start=1&amp;where=web" onclick="return goOtherCR(this, 'a=pag.pag&amp;r=11&amp;i=&amp;u='+urlencode(this.href ? this.href : location.href))" role="button"><i class="spnew ico_page_arr">다음</i></a> </div> </div> </link></link></div><div class="sub_pack" id="sub_pack"><section class="sc_new sp_nkeyword" id="nx_right_related_keywords"> <div class="api_subject_bx _related_box"> <div class="a ...

# %% [markdown]
# #### 4. bs object > .select(css-selector), .select_one(css-selector) > str(text)
# #### copy -> copy selector

# %%
elements = dom.select("#nx_right_related_keywords > div > div.related_srch > ul > li")
len(elements)
#nx_right_related_keywords > div > div.related_srch > ul > li
# Out:
# 10

# %%
element = elements[0]
element.select_one(".tit").text
# Out:
# '삼성전자주가'

# %% [markdown]
# #### 5. str(text) > DataFrame

# %%
keywords = [element.select_one(".tit").text for element in elements]
keywords
# Out:
# ['삼성전자주가',
#  '삼성전자 배당금',
#  '삼성전자 성과급',
#  '삼성전자 주식',
#  '삼성전자서비스',
#  '오늘 삼성전자 주가',
#  '삼성전자 배당금 지급일',
#  '삼성전자 세일 페스타',
#  '삼성 전자레인지',
#  '삼성전자 opi']

# %%
df = pd.DataFrame({"keyword" : keywords})
df["query"] = query
df
# Out:
#         keyword query
# 0        삼성전자주가  삼성전자
# 1      삼성전자 배당금  삼성전자
# 2      삼성전자 성과급  삼성전자
# 3       삼성전자 주식  삼성전자
# 4       삼성전자서비스  삼성전자
# 5    오늘 삼성전자 주가  삼성전자
# 6  삼성전자 배당금 지급일  삼성전자
# 7   삼성전자 세일 페스타  삼성전자
# 8      삼성 전자레인지  삼성전자
# 9      삼성전자 opi  삼성전자

# %%
#현재 시간 데이터 추가
from datetime import datetime
now = datetime.now()
now = now.strftime("%Y-%m-%d %H : %M")
df["date_time"] = now
df.tail(2)
# Out:
#     keyword query           date_time
# 8  삼성 전자레인지  삼성전자  2023-02-19 23 : 56
# 9  삼성전자 opi  삼성전자  2023-02-19 23 : 56

# %%
#query를 입력하면 데이터 프레임을 출력하는 함수
def naver_relate_keyword(query):
    url = f"https://search.naver.com/search.naver?query={query}"
    response = requests.get(url)
    dom = BeautifulSoup(response.text, "html.parser")
    elements = dom.select(".lst_related_srch > .item")
    keywords = [element.text.strip() for element in elements]
    df = pd.DataFrame({"keywords" : keywords})
    df["query"] = query
    now = datetime.now()
    now = now.strftime("%Y-%m-%d %H : %M")
    df["date_time"] = now
    return df

query = "삼성전자"
df = naver_relate_keyword(query)
df.tail(2)
# Out:
#    keywords query           date_time
# 8  삼성 전자레인지  삼성전자  2023-02-20 00 : 01
# 9  삼성전자 opi  삼성전자  2023-02-20 00 : 01

# %%
dfs = []
queries = ["삼성전자", "LG전자"]
for query in queries:
    print(query, end = " ")
    df = naver_relate_keyword(query)
    dfs.append(df)
result = pd.concat(dfs, ignore_index = True)
result
# Out:
# 삼성전자 LG전자
#            keywords query           date_time
# 0            삼성전자주가  삼성전자  2023-02-20 00 : 03
# 1          삼성전자 배당금  삼성전자  2023-02-20 00 : 03
# 2          삼성전자 성과급  삼성전자  2023-02-20 00 : 03
# 3           삼성전자 주식  삼성전자  2023-02-20 00 : 03
# 4           삼성전자서비스  삼성전자  2023-02-20 00 : 03
# 5        오늘 삼성전자 주가  삼성전자  2023-02-20 00 : 03
# 6      삼성전자 배당금 지급일  삼성전자  2023-02-20 00 : 03
# 7       삼성전자 세일 페스타  삼성전자  2023-02-20 00 : 03
# 8          삼성 전자레인지  삼성전자  2023-02-20 00 : 03
# 9          삼성전자 opi  삼성전자  2023-02-20 00 : 03
# 10       lg전자 서비스센터  LG전자  2023-02-20 00 : 03
# 11          lg전자 주가  LG전자  2023-02-20 00 : 03
# 12        lg전자 베스트샵  LG전자  2023-02-20 00 : 03
# 13         lg전자 성과급  LG전자  2023-02-20 00 : 03
# 14         lg 전자레인지  LG전자  2023-02-20 00 : 03
# 15  lg전자 서비스센터 전화번호  LG전자  2023-02-20 00 : 03
# 16        lg전자 고객센터  LG전자  2023-02-20 00 : 03
# 17           lg전자렌지  LG전자  2023-02-20 00 : 03
# 18         lg전자 배당금  LG전자  2023-02-20 00 : 03
# 19          lg전자 렌탈  LG전자  2023-02-20 00 : 03
