# %% [markdown]
# <center><img src='https://raw.githubusercontent.com/Jangrae/img/master/ml_python.png' width=600/></center>

# %% [markdown]
# # 실습 내용
#
# - AirQuality 데이터에 대해 모델링합니다.
# - KNN 알고리즘을 사용해 모델링합니다.

# %% [markdown]
# # 1.환경 준비
#
# - 기본 라이브러리와 대상 데이터를 가져와 이후 과정을 준비합니다.

# %%
# 라이브러리 불러오기
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings(action='ignore')
# %config InlineBackend.figure_format='retina'

# %%
# 데이터 읽어오기
path = 'https://raw.githubusercontent.com/Jangrae/csv/master/airquality_simple.csv'
data = pd.read_csv(path)

# %% [markdown]
# # 2.데이터 이해
#
# - 분석할 데이터를 충분히 이해할 수 있도록 다양한 탐색 과정을 수행합니다.

# %%
# 상위 몇 개 행 확인
data.head()
# Out:
#    Ozone  Solar.R  Wind  Temp  Month  Day
# 0     41    190.0   7.4    67      5    1
# 1     36    118.0   8.0    72      5    2
# 2     12    149.0  12.6    74      5    3
# 3     18    313.0  11.5    62      5    4
# 4     19      NaN  14.3    56      5    5

# %%
# 기술통계 확인
data.describe()
# Out:
#             Ozone     Solar.R        Wind        Temp       Month         Day
# count  153.000000  146.000000  153.000000  153.000000  153.000000  153.000000
# mean    42.052288  185.931507    9.957516   77.882353    6.993464   15.803922
# std     30.156127   90.058422    3.523001    9.465270    1.416522    8.864520
# min      1.000000    7.000000    1.700000   56.000000    5.000000    1.000000
# 25%     20.000000  115.750000    7.400000   72.000000    6.000000    8.000000
# 50%     34.000000  205.000000    9.700000   79.000000    7.000000   16.000000
# 75%     59.000000  258.750000   11.500000   85.000000    8.000000   23.000000
# max    168.000000  334.000000   20.700000   97.000000    9.000000   31.000000

# %%
# 상관관계 확인
data.corr()
# Out:
#             Ozone   Solar.R      Wind      Temp     Month       Day
# Ozone    1.000000  0.280068 -0.605478  0.683372  0.174197  0.004419
# Solar.R  0.280068  1.000000 -0.056792  0.275840 -0.075301 -0.150275
# Wind    -0.605478 -0.056792  1.000000 -0.457988 -0.178293  0.027181
# Temp     0.683372  0.275840 -0.457988  1.000000  0.420947 -0.130593
# Month    0.174197 -0.075301 -0.178293  0.420947  1.000000 -0.007962
# Day      0.004419 -0.150275  0.027181 -0.130593 -0.007962  1.000000

# %% [markdown]
# # 3.데이터 준비
#
# - 전처리 과정을 통해 머신러닝 알고리즘에 사용할 수 있는 형태의 데이터를 준비합니다.

# %% [markdown]
# **1) 결측치 처리**
#
# - 결측치가 있으면 제거하거나 적절한 값으로 채웁니다.
# - 시계열 데이터이므로 선형보간법으로 채웁니다.

# %%
# 결측치 확인
data.isnull().sum()
# Out:
# Ozone      0
# Solar.R    7
# Wind       0
# Temp       0
# Month      0
# Day        0
# dtype: int64

# %%
# 결측치 채우기
data.interpolate(method='linear', inplace=True)

# 확인
data.isnull().sum()
# Out:
# Ozone      0
# Solar.R    0
# Wind       0
# Temp       0
# Month      0
# Day        0
# dtype: int64

# %% [markdown]
# **2) 변수 제거**
#
# - 분석에 의미가 없다고 판단되는 변수는 제거합니다.
# - Month, Day 열을 제거합니다.

# %%
#  변수 제거
drop_cols = ['Month', 'Day']
data.drop(drop_cols, axis=1, inplace=True)

# 확인
data.head()
# Out:
#    Ozone     Solar.R  Wind  Temp
# 0     41  190.000000   7.4    67
# 1     36  118.000000   8.0    72
# 2     12  149.000000  12.6    74
# 3     18  313.000000  11.5    62
# 4     19  308.333333  14.3    56

# %% [markdown]
# **3) x, y 분리**
#
# - target 변수를 명확히 지정합니다.
# - target을 제외한 변수를 x 데이터프레임으로 선언합니다.
# - y 데이터프레임은 target 변수만을 가집니다.

# %%
# target 확인
target = 'Ozone'

# 데이터 분리
x = data.drop(target, axis=1)
y = data.loc[:, target]

# %% [markdown]
# **4) 학습용, 평가용 데이터 분리**
#
# - 학습용, 평가용 데이터를 적절한 비율로 분리합니다.
# - 반복 실행 시 동일한 결과를 얻기 위해 random_state 옵션을 지정합니다.

# %%
# 모듈 불러오기
from sklearn.model_selection import train_test_split

# 데이터 분리
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1)

# %% [markdown]
# **5) 정규화**
#
# - KNN 알고리즘을 사용하기 위해 정규화를 진행합니다.

# %%
# 모듈 불러오기
from sklearn.preprocessing import MinMaxScaler

# 정규화
scaler = MinMaxScaler()
scaler.fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test) #x_test에서 배운 대로 정규화(x_test의 최솟값, 최댓값 사용)

# %% [markdown]
# # 4.모델링
#
# - 본격적으로 모델을 선언하고 학습하고 평가하는 과정을 진행합니다.

# %%
# 1단계: 불러오기
from sklearn.neighbors import KNeighborsRegressor
from sklearn.metrics import mean_absolute_error, r2_score

# %%
# 2단계: 선언하기
model = KNeighborsRegressor()

# %%
# 3단계: 학습하기
model.fit(x_train, y_train)
# Out:
# KNeighborsRegressor()

# %%
# 4단계 예측하기
y_pred = model.predict(x_test)

# %%
# 5단계: 평가하기
print('MAE:', mean_absolute_error(y_test, y_pred))
print('R2-Score:', r2_score(y_test, y_pred))
# Out:
# MAE: 12.443478260869565
# R2-Score: 0.6168024614834005

# %% [markdown]
# # 5.기타
#
# - 모델이 복잡하다는 것은
#     - 학습 데이터에 너무 치중한 나머지 실제 평가시 성능이 좋지 않은 것
#     - 즉 과대적합 위험이 있는 것을 의미
# - Linear Regression : 독립 변수가 너무 많은 모델
# - KNN : K값, 즉 n_neighbors 값이 작을 수록
# - Decision Tree : max_depth가 클수록 복잡한 모델
# - 결국 우리는 적당한 복잡성을 갖는 모델을 만들어야 함
# - 너무 단순해도 안되고, 복잡해도 안됨

# %% [markdown]
# **1) 학습 성능**
#
# - n_neighbors 값을 학습 데이터 건수로 하면 가장 단순한 모델, 즉 평균이 됩니다.
# - n_neighbors 값을 1로 하면 가장 복잡한 모델이 되며 정답, 즉 y_train 값을 외운 결과가 됩니다.
# - n_neighbors 값에 따라 학습 데이터를 얼마나 깊이 있게 학습했는지 확인합니다.

# %%
# 모델 복잡도
plt.figure(figsize=(10, 8))
for i, n in enumerate([1, 2, 3, 4, 8, 20, 50, 80, len(x_train)]):
    model = KNeighborsRegressor(n_neighbors=n)
    model.fit(x_train, y_train)
    y_pred = model.predict(x_train)
    print(y_pred)
    plt.subplot(3, 3, i+1)
    plt.plot(y_train.values, label='y_train')    # 학습할 정답
    plt.plot(y_pred, label='y_pred')             # x_train 학습하고 예측한 정답
    plt.title(f'k={n}')
    plt.legend()
    plt.ylabel('Ozone')
plt.tight_layout()
plt.show()
# Out:
# [ 24.  27.  30.  20.  19.  26.   7.  71.  26.  87.  24.  59.  11.  30.
#   80.  96.   9.  16.  24.  12.  65.  23.  41.  44.  64.  44.  28.  28.
#   21.  49.  42.  73.  16.  18.  64.   7.  48.  29.  73.  62.  49.  21.
#   20.  23.  32.  77.  20.  21. 122. 118.  13.  52.  16.  31.  39.  14.
#   50.  56.  63.  70.  15.  48.  23.  17.  23. 168.  23.  12.  11.  85.
#   18.   7.  37.  14.  32.  37.  45.  14.  82.   8.  16.  66.  32.  36.
#   23.   4. 135.  32.  19.  20.  35.  97.  13.  18.  79.   1.  18.  21.
#   46.  20.  23.  79.  44.  13.  10.  13.  29.]
# [ 26.5  24.   22.   12.   18.5  37.5  19.5  56.5  23.5  91.5  20.   37.5
#   17.   35.5  71.   90.5  16.   20.   17.   17.5  55.5  17.   30.5  44.5
#   71.5  31.   38.5  17.5  17.5  56.5  56.5  77.5  18.   31.   56.   17.5
#   32.   26.5  95.5  69.5  38.5  21.   22.   16.   25.5  99.5  30.5  26.
#   99.5  95.5  15.5  45.5  32.   25.5  45.5  16.   35.   67.5  56.   64.5
#   23.5  56.   44.5  18.   17.5 151.5  34.   12.5  10.5  90.5  16.    8.
#   33.   17.5  22.5  24.   34.   15.   77.5  12.5  19.5  44.5  19.5  40.
#   16.    2.5 106.   41.   25.5  18.   29.   87.   12.5  15.5  80.5   2.5
#   18.5  21.   56.   25.5  16.   83.   35.   12.5  15.5  18.   37.5]
# [ 23.          23.66666667  19.33333333  10.33333333  18.33333333
#   34.33333333  23.66666667  56.33333333  22.66666667  87.33333333
#   20.          31.66666667  16.          30.33333333  63.66666667
#   89.33333333  18.33333333  18.          18.33333333  15.66666667
#   46.66666667  16.          30.33333333  37.33333333  76.66666667
#   32.66666667  32.33333333  27.66666667  20.66666667  48.33333333
#   56.33333333  57.          31.66666667  32.66666667  53.66666667
#   21.66666667  33.          30.          90.          73.
#   34.33333333  22.66666667  20.66666667  13.          18.33333333
#   87.          30.33333333  25.         111.33333333 104.33333333
#   17.          41.          45.66666667  24.66666667  40.
#   20.66666667  34.          68.66666667  53.33333333  48.33333333
#   29.33333333  46.66666667  45.          14.66666667  16.
#  110.33333333  33.          12.33333333  14.          72.
#   20.66666667  13.          31.33333333  15.66666667  17.33333333
#   23.          37.33333333  18.          80.          14.66666667
#   32.66666667  45.          30.33333333  32.66666667  15.
#    8.33333333 126.66666667  42.33333333  22.66666667  25.
#   41.33333333  78.66666667  14.33333333  17.          78.
#    8.33333333  16.66666667  22.66666667  45.          33.66666667
#   18.33333333  76.66666667  30.33333333  12.33333333  18.33333333
#   15.          47.        ]
# [ 22.5   21.25  19.    13.5   17.25  33.    30.75  54.5   28.    86.75
#   18.5   27.75  16.    24.5   63.75  86.75  15.5   19.5   21.5   15.
#   40.75  16.5   28.75  44.25  66.25  27.75  36.75  30.    21.25  48.75
#   54.5   54.75  40.25  27.75  48.25  25.5   43.    26.5   89.25  70.75
#   30.75  19.5   18.75  14.75  18.75  99.    28.75  24.75 107.75 102.5
#   18.75  38.75  45.5   23.75  35.    21.25  32.5   63.75  45.    40.25
#   26.75  43.    42.5   19.    15.    94.75  30.    12.5   15.75  75.75
#   18.25  14.75  35.5   17.5   22.75  22.5   36.    16.25  79.75  16.75
#   27.75  41.    32.5   27.75  13.    12.   125.5   36.75  18.    26.
#   52.25  89.5   21.75  18.75  72.5   12.    17.    19.5   41.    32.25
#   15.5   78.75  28.    12.5   19.    17.    51.5 ]
# [ 24.5    31.     19.375  13.75   17.125  31.5    25.875  54.125  24.25
#   66.875  17.75   29.375  18.75   28.75   53.75   77.     16.75   20.125
#   21.75   19.     41.75   18.75   24.25   36.625  67.25   32.125  35.625
#   50.     22.875  59.125  47.375  56.5    37.25   34.25   57.25   26.75
#   43.875  24.5    90.5    76.5    38.75   22.25   18.25   13.75   15.875
#   85.625  22.375  29.    107.625  99.625  17.625  28.375  39.5    30.75
#   37.5    18.125  37.125  67.125  41.875  34.875  22.625  46.25   41.
#   15.5    23.375  88.25   33.25   21.375  22.5    73.125  17.75   16.375
#   35.875  23.25   26.875  23.5    29.     20.25   73.875  14.125  21.25
#   41.5    30.125  23.25   17.875  14.875  88.     39.25   17.875  38.375
#   50.75   91.75   27.     17.125  77.125  14.875  16.75   22.25   41.25
#   34.75   16.75   75.125  24.75   17.375  19.     22.75   37.625]
# [24.3  31.15 20.1  20.95 19.7  30.95 21.25 46.15 27.95 60.   21.45 30.1
#  20.7  28.6  60.35 68.35 18.95 22.8  25.25 26.6  32.65 21.7  22.6  33.3
#  67.55 30.45 41.15 45.05 26.05 49.9  43.85 59.   36.6  30.85 58.25 31.5
#  53.15 26.2  83.1  72.3  40.75 26.75 21.95 18.7  18.   77.2  24.65 24.8
#  83.35 84.65 19.6  32.85 49.3  35.95 31.65 19.95 40.5  60.35 46.15 35.75
#  20.15 56.35 43.8  15.25 28.65 66.25 36.5  26.   24.4  61.1  18.85 20.5
#  35.35 23.5  24.3  21.75 38.95 20.2  67.9  16.5  22.95 46.65 27.95 29.65
#  20.4  20.9  74.05 42.55 16.25 36.4  55.6  83.75 32.55 18.5  69.1  19.1
#  19.25 24.8  43.8  37.   19.2  77.95 32.65 23.95 21.1  22.55 36.3 ]
# [30.84 34.46 28.92 25.5  23.9  36.8  30.88 47.52 33.36 57.28 25.7  35.38
#  30.22 32.98 54.48 56.08 26.82 27.22 28.9  27.64 39.06 32.04 30.3  34.56
#  56.24 32.82 41.18 46.38 29.44 54.44 47.8  56.22 37.8  35.82 55.76 42.18
#  47.62 35.68 57.22 57.14 40.7  30.28 24.52 25.9  22.6  56.84 28.84 29.74
#  56.84 56.74 23.7  38.12 52.34 32.82 38.12 27.98 48.12 54.54 43.78 39.26
#  22.9  52.26 43.38 21.22 28.26 55.32 32.86 27.02 29.2  55.32 27.18 26.32
#  44.9  27.98 34.18 27.36 38.42 27.36 56.58 23.32 33.04 44.42 33.44 28.5
#  27.94 24.92 55.16 47.82 20.5  36.9  54.32 57.24 30.08 24.7  57.5  24.92
#  23.5  30.28 40.28 36.08 28.98 55.8  35.96 25.86 27.44 32.26 38.68]
# [40.4875 35.9375 39.2    32.1375 32.2375 41.5125 32.75   44.075  40.
#  45.1375 35.925  41.225  39.275  37.0625 43.75   45.5875 32.1875 38.55
#  39.0375 31.7125 41.6625 39.275  33.5    42.725  44.5125 37.05   41.9875
#  42.8125 33.125  44.2875 44.0375 44.9625 42.8625 37.5    43.825  41.35
#  44.9125 40.7625 45.6125 44.2875 43.3    37.1875 34.475  30.9    26.3875
#  44.8    34.9875 39.6625 45.5375 45.675  31.85   39.6125 44.7875 41.775
#  39.5    38.45   43.6875 44.2875 44.45   41.95   28.05   43.8375 44.3625
#  25.725  33.85   44.6875 42.225  31.1875 37.8875 45.6875 36.55   31.9375
#  43.425  31.35   33.25   32.3125 42.4875 37.7625 44.9625 25.725  37.1875
#  44.3625 34.7375 34.4375 32.1875 29.325  45.0625 43.825  25.75   42.4125
#  45.4125 45.0625 35.8875 29.75   44.9125 28.9375 30.0125 38.3    44.3625
#  41.775  34.1625 45.7625 37.9875 30.1875 37.475  34.8375 41.4875]
# [38.36448598 38.36448598 38.36448598 38.36448598 38.36448598 38.36448598
#  38.36448598 38.36448598 38.36448598 38.36448598 38.36448598 38.36448598
#  38.36448598 38.36448598 38.36448598 38.36448598 38.36448598 38.36448598
#  38.36448598 38.36448598 38.36448598 38.36448598 38.36448598 38.36448598
#  38.36448598 38.36448598 38.36448598 38.36448598 38.36448598 38.36448598
#  38.36448598 38.36448598 38.36448598 38.36448598 38.36448598 38.36448598
#  38.36448598 38.36448598 38.36448598 38.36448598 38.36448598 38.36448598
#  38.36448598 38.36448598 38.36448598 38.36448598 38.36448598 38.36448598
#  38.36448598 38.36448598 38.36448598 38.36448598 38.36448598 38.36448598
#  38.36448598 38.36448598 38.36448598 38.36448598 38.36448598 38.36448598
#  38.36448598 38.36448598 38.36448598 38.36448598 38.36448598 38.36448598
#  38.36448598 38.36448598 38.36448598 38.36448598 38.36448598 38.36448598
#  38.36448598 38.36448598 38.36448598 38.36448598 38.36448598 38.36448598
#  38.36448598 38.36448598 38.36448598 38.36448598 38.36448598 38.36448598
#  38.36448598 38.36448598 38.36448598 38.36448598 38.36448598 38.36448598
#  38.36448598 38.36448598 38.36448598 38.36448598 38.36448598 38.36448598
#  38.36448598 38.36448598 38.36448598 38.36448598 38.36448598 38.36448598
#  38.36448598 38.36448598 38.36448598 38.36448598 38.36448598]

# %% [markdown]
# **2) 평가 성능**
#
# - n_neighbors 값에 따라 평가 성능이 어느 정도 인지 확인합니다.

# %%
# 모델 복잡도
plt.figure(figsize=(10, 8))
for i, n in enumerate([1, 2, 3, 4, 8, 20, 50, 80, len(x_train)]):
    model = KNeighborsRegressor(n_neighbors=n)
    model.fit(x_train, y_train)
    y_pred = model.predict(x_test)
    print(y_pred)
    r2 = r2_score(y_test, y_pred)
    plt.subplot(3, 3, i+1)
    plt.plot(y_test.values, label='y_test') 
    plt.plot(y_pred, label='y_pred') #x_test 학습하고 예측한 정답      
    plt.title(f'k={n}, R2={r2:.2f}')
    plt.legend()
    plt.ylabel('Ozone')
plt.tight_layout()
plt.show()
# Out:
# [ 7. 18. 97. 16. 37. 32. 79. 19. 59. 26.  8. 28. 62. 39. 30. 73. 30. 82.
#  62. 66. 50. 73. 16. 79.  7. 49. 28. 79. 28. 96. 73.  4.  9. 63. 28. 29.
#  32. 97. 18. 44. 18. 18. 49. 17. 79. 73.]
# [ 19.5  14.   87.   18.   33.   27.5 100.5  25.5  64.5  37.5  12.5  38.
#   55.   34.   22.   77.5  22.   80.5  71.   76.5  41.   84.5  18.   67.5
#   19.5  60.   98.   67.5  17.5  90.5  61.   12.   16.   55.5  39.   47.
#   35.5  88.   31.   35.   31.   31.   37.5  12.5  67.5  84.5]
# [17.33333333 13.66666667 98.66666667 34.         38.66666667 22.66666667
#  94.33333333 22.66666667 49.         33.66666667 16.         27.66666667
#  58.         40.         20.66666667 68.         20.66666667 82.
#  68.66666667 62.66666667 34.         82.66666667 31.66666667 66.
#  17.33333333 66.66666667 81.33333333 77.33333333 24.         86.66666667
#  46.          8.33333333 13.         61.33333333 42.33333333 46.66666667
#  33.33333333 98.         36.         30.33333333 28.33333333 32.66666667
#  34.33333333 14.66666667 77.         82.66666667]
# [ 15.25  15.5   89.5   37.    41.    22.    86.75  18.    40.75  32.25
#   16.75  30.    77.25  41.5   18.25  55.    19.    79.75  63.75  52.75
#   37.75  83.25  40.25  61.75  21.    57.    62.75  78.5   30.    85.5
#   55.     8.    15.5   58.25  36.75  40.75  38.   104.    32.75  28.
#   32.75  27.75  45.75  19.    79.    91.5 ]
# [23.875 16.875 91.75  40.75  33.875 21.    95.    15.375 34.875 25.75
#  14.875 34.625 79.625 46.    16.    51.5   17.375 72.125 76.5   48.375
#  40.25  87.375 34.625 66.875 25.875 50.125 53.375 72.25  51.    87.375
#  53.375 14.875 15.875 50.375 42.375 41.125 27.5   93.    38.    25.625
#  45.25  27.    46.625 14.625 78.875 92.75 ]
# [20.9  19.8  83.75 50.15 35.75 25.55 83.   17.3  35.45 32.9  15.7  47.2
#  65.85 42.7  19.55 53.05 19.15 68.3  62.8  52.3  42.4  77.05 36.6  59.3
#  23.05 50.75 55.65 66.5  42.2  73.2  53.85 18.85 19.25 46.7  40.35 34.1
#  27.7  79.85 35.3  31.6  34.65 33.15 44.35 15.05 73.4  83.1 ]
# [26.62 24.76 57.24 45.78 44.64 33.54 55.6  22.34 40.04 32.46 24.42 47.9
#  56.34 40.92 27.   55.92 28.14 56.64 57.14 49.92 49.62 57.04 38.18 57.84
#  31.8  46.5  52.24 57.64 45.14 57.04 54.04 24.92 25.88 45.22 47.46 37.98
#  34.2  57.16 37.4  35.92 43.38 36.14 44.8  21.56 58.08 56.8 ]
# [32.75   30.6875 44.8    44.3375 43.425  35.0875 45.4375 26.05   41.0375
#  41.5125 26.325  43.475  43.825  43.0625 36.325  44.9625 38.225  44.9125
#  44.2875 44.4125 43.6875 45.6875 42.3625 44.45   33.25   43.7625 44.025
#  44.575  43.2125 45.6875 44.45   29.325  31.3625 44.625  43.75   39.4375
#  34.6125 45.7    40.7    39.4125 42.3    37.75   43.7625 25.2    44.675
#  45.625 ]
# [38.36448598 38.36448598 38.36448598 38.36448598 38.36448598 38.36448598
#  38.36448598 38.36448598 38.36448598 38.36448598 38.36448598 38.36448598
#  38.36448598 38.36448598 38.36448598 38.36448598 38.36448598 38.36448598
#  38.36448598 38.36448598 38.36448598 38.36448598 38.36448598 38.36448598
#  38.36448598 38.36448598 38.36448598 38.36448598 38.36448598 38.36448598
#  38.36448598 38.36448598 38.36448598 38.36448598 38.36448598 38.36448598
#  38.36448598 38.36448598 38.36448598 38.36448598 38.36448598 38.36448598
#  38.36448598 38.36448598 38.36448598 38.36448598]
